# %%
import pandas as pd 
import numpy as np 
import matplotlib.pyplot as plt 
from preprocessing.scripts.load_and_prepare_all_dish import load_and_prepare_dish
from preprocessing.scripts.load_and_prepare_wine_article import load_and_prepare_wine_articles, change_article_category
from preprocessing.scripts.prepare_for_abc_analys_merge import process_wine_sales
from preprocessing.scripts.add_time_columns_dish import add_time_columns

# %%
dish = load_and_prepare_dish('/Users/nl/streamlit_test/data/Отчет_по_блюдам_все время.xlsx')
article = load_and_prepare_wine_articles('/Users/nl/streamlit_test/data/Блюда артикулы.xlsx')

# %%
dish.head()
# Out:
#    article               dish           open_time  session_id  order_id  \
# 0     41.0   дом диого аринту 2024-06-15 18:47:00       266.0    2638.0
# 1     41.0   дом диого аринту 2023-10-14 21:43:00        22.0     166.0
# 2     41.0   дом диого аринту 2024-02-08 21:17:00       138.0    1159.0
# 3     41.0   дом диого аринту 2024-02-08 21:17:00       138.0    1159.0
# 4     41.0   дом диого аринту 2024-04-28 18:19:00       218.0    2068.0
#
#    table_no   price  quantity  total_sum  discount  final_sum  \
# 0       1.0  2300.0       1.0     2300.0       0.0     2300.0
# 1       1.0  2300.0       0.2      460.0       0.0      460.0
# 2       1.0  2300.0       0.2      460.0       0.0      460.0
# 3       1.0  2300.0       0.2      460.0       0.0      460.0
# 4       1.0  2300.0       1.0     2300.0       0.0     2300.0
#
#        payment_type  guest_no
# 0  банковские карты       1.0
# 1  банковские карты       1.0
# 2  банковские карты       1.0
# 3  банковские карты       1.0
# 4  банковские карты       1.0

# %%
article.head()
# Out:
#    article_category only_glass_cat                           article_name  \
# 33       белые вина         другое           альхайт вайнери хирафте хиа
# 34       белые вина         другое                  балаша фурминт токай
# 35       белые вина         другое         бенанти этна бьянко карриканте
# 36       белые вина         другое      бернхард хубер мальтердингер вайс
# 37       белые вина         другое  блдега эль порвенир лаборум торронтес
#
#     article  article_price  article_profit  article_profit_percent
# 33     1616         7900.0         3040.60                   38.49
# 34     1198         3500.0         1058.28                   30.24
# 35     1617         6900.0         2648.78                   38.39
# 36       73         8900.0         5103.70                   57.34
# 37     1759         2900.0         1203.80                   41.51

# %%
article = change_article_category(article)

# %%
article.sample(20)
# Out:
#            article_category    only_glass_cat  \
# 45               белые_вина        белые_вина
# 292            красные_вина      красные_вина
# 43               белые_вина        белые_вина
# 290            красные_вина      красные_вина
# 55               белые_вина        белые_вина
# 260            красные_вина      красные_вина
# 152  вина_по_бокалам_150_мл  дижестивы_оранжи
# 298            красные_вина      красные_вина
# 328                игристые          игристые
# 269            красные_вина      красные_вина
# 178  вина_по_бокалам_150_мл      красные_вина
# 82               белые_вина        белые_вина
# 149  вина_по_бокалам_150_мл  дижестивы_оранжи
# 206        дижестивы_оранжи  дижестивы_оранжи
# 166  вина_по_бокалам_150_мл          игристые
# 129          вина_вне_карты    вина_вне_карты
# 34               белые_вина        белые_вина
# 278            красные_вина      красные_вина
# 35               белые_вина        белые_вина
# 257            красные_вина      красные_вина
#
#                                           article_name  article  \
# 45   домен вахау рислинг федершпиль  рид лойбенберг...     1967
# 292                шато фелан сегюр сент-эстеф франция     1886
# 43                     домен боржо бузерон ле турнель       492
# 290                 шато ляфон роше сент-эстеф франция      116
# 55   карл шафер михельсберг дюркхаймер рислинг гг 2020     2259
# 260                       жерар рафе бургонь пастугрен       99
# 152  мишель шапутье ривзальт лангедок-руссильон фра...     1824
# 298        солнечная долина меганом резерв крым россия     1921
# 328       николя майяр розе бузи гран крю брют шампань      550
# 269                     пол клювер пино нуар элгин юар       89
# 178  солнечная долина меганом резерв кубань россия ...     2159
# 82                                   гай-кадзор вионье      134
# 149  клостер эбербах хоххаймер домдехана рислинг шп...     2173
# 206                          ла ина фино херес испания     2321
# 166      филипп мишель креман брют жура франция 150 мл     2147
# 129                         мартинет бру риоха испания     1881
# 34                               балаша фурминт токай      1198
# 278                                   сэвидж вайнс ред     1919
# 35                      бенанти этна бьянко карриканте     1617
# 257       домэн де ля вужере жевре-шамбертан ля жустик     1883
#
#      article_price  article_profit  article_profit_percent
# 45          3900.0         1243.73                   31.89
# 292        18900.0         5099.15                   26.98
# 43         11500.0         4572.40                   39.76
# 290        10900.0         7935.00                   72.80
# 55         10900.0         6751.65                   61.94
# 260        16500.0         8275.40                   50.15
# 152          980.0          433.42                   44.23
# 298         2900.0          893.58                   30.81
# 328        13900.0         2725.65                   19.61
# 269         6100.0         2462.15                   40.36
# 178          580.0          178.72                   30.81
# 82          2500.0          621.00                   24.84
# 149          890.0          353.67                   39.74
# 206         3500.0         1246.67                   35.62
# 166         1100.0          412.90                   37.54
# 129        11000.0         4542.50                   41.30
# 34          3500.0         1058.28                   30.24
# 278        10900.0         4345.85                   39.87
# 35          6900.0         2648.78                   38.39
# 257        26500.0        10617.95                   40.07

# %%
df = process_wine_sales(dish, article)

# %%
df.sample(20)
# Out:
#                open_time                                       article_name  \
# 3512 2025-01-29 13:23:00                                шато ситран о-медок
# 2578 2023-12-27 18:46:00              узунов розе экстра брют кубань россия
# 3358 2025-07-08 13:41:00                   пьетрозо брунелло ди монтальчино
# 1098 2025-03-08 19:32:00                балаша фурминт токай венгрия 150 мл
# 838  2025-05-01 17:05:00                             узунов вайнери алиготе
# 3377 2024-02-17 21:12:00                   пьетрозо брунелло ди монтальчино
# 3340 2023-11-17 18:56:00                     пол клювер пино нуар элгин юар
# 2713 2024-04-18 17:50:00                       кроне розе mкк кюве брют юар
# 524  2023-12-13 16:55:00        ник вайс ст. урбанс-хоф, рислинг "лайет" гг
# 2555 2024-09-17 13:33:00              узунов розе экстра брют кубань россия
# 3330 2023-12-02 12:28:00                     пол клювер пино нуар элгин юар
# 2446 2025-06-09 14:11:00                                          глоу брют
# 385  2024-05-31 18:55:00                         кальтерн кальдаро кей уайт
# 2681 2024-01-04 19:28:00                 кинта да раза  пет-нат бранко брют
# 1857 2025-07-15 16:21:00                     шато гиро сотерн франция 75 мл
# 2085 2025-08-16 21:18:00      филипп мишель креман брют жура франция 150 мл
# 591  2025-06-21 18:49:00                                рейнеке резерв уайт
# 3155 2025-01-26 19:49:00  грейт бонза резерв шираз каберне южная австралия
# 2414 2025-01-07 19:47:00      клостер эбербах хоххаймер домдеханей шпетлезе
# 2500 2025-06-12 22:21:00             узунов гладь экстра брют кубань россия
#
#         price  quantity  final_sum        article_category    only_glass_cat  \
# 3512   6300.0       1.0     6300.0            красные_вина      красные_вина
# 2578   2100.0       2.0      840.0                игристые          игристые
# 3358  16900.0       1.0     3380.0            красные_вина      красные_вина
# 1098    620.0       1.0      620.0  вина_по_бокалам_150_мл        белые_вина
# 838    2300.0       1.0     2300.0              белые_вина        белые_вина
# 3377  12900.0       1.0     2580.0            красные_вина      красные_вина
# 3340   4100.0       2.0     1640.0            красные_вина      красные_вина
# 2713   2900.0       2.0     1160.0                игристые          игристые
# 524    9600.0       1.0     1920.0              белые_вина        белые_вина
# 2555   2100.0       1.0     2100.0                игристые          игристые
# 3330   4100.0       1.0      820.0            красные_вина      красные_вина
# 2446   1600.0       1.0      320.0                игристые          игристые
# 385    2900.0       2.0     1160.0              белые_вина        белые_вина
# 2681   3300.0       1.0      660.0                игристые          игристые
# 1857   2090.0       1.0     2090.0  вина_по_бокалам_150_мл  дижестивы_оранжи
# 2085   1100.0       1.0      935.0  вина_по_бокалам_150_мл          игристые
# 591    5100.0       1.0      867.0              белые_вина        белые_вина
# 3155   2900.0       2.0     1160.0            красные_вина      красные_вина
# 2414   5900.0       1.0     1180.0        дижестивы_оранжи  дижестивы_оранжи
# 2500   3100.0       1.0     3100.0                игристые          игристые
#
#       article_price  article_profit    glass  glass_price  glass_profit
# 3512         7500.0         1619.65  бутылка       7500.0      1619.650
# 2578         3100.0         1104.00    бокал        620.0       220.800
# 3358        16900.0         5953.78    бокал       3380.0      1190.756
# 1098          700.0          158.74    бокал        700.0       158.740
# 838          3100.0          920.72  бутылка       3100.0       920.720
# 3377        16900.0         5953.78    бокал       3380.0      1190.756
# 3340         6100.0         2462.15    бокал       1220.0       492.430
# 2713         3500.0         1321.34    бокал        700.0       264.268
# 524         14000.0         5125.84    бокал       2800.0      1025.168
# 2555         3100.0         1104.00  бутылка       3100.0      1104.000
# 3330         6100.0         2462.15    бокал       1220.0       492.430
# 2446         1750.0          337.82    бокал        350.0        67.564
# 385          3300.0          809.11    бокал        660.0       161.822
# 2681         3500.0         1049.28    бокал        700.0       209.856
# 1857         2090.0          588.39    бокал       2090.0       588.390
# 2085         1100.0          412.90    бокал       1100.0       412.900
# 591          8100.0         3183.68    бокал       1620.0       636.736
# 3155         3100.0         1085.60    бокал        620.0       217.120
# 2414         8900.0         3536.74    бокал       1780.0       707.348
# 2500         3100.0         1104.00  бутылка       3100.0      1104.000

# %%
df.article_category.unique()
# Out:
# array(['белые_вина', 'вина_вне_карты', 'вина_по_бокалам_150_мл',
#        'дижестивы_оранжи', 'игристые', 'красные_вина'], dtype=object)

# %%
df.only_glass_cat.unique()
# Out:
# array(['белые_вина', 'вина_вне_карты', 'дижестивы_оранжи', 'игристые',
#        'красные_вина'], dtype=object)

# %%
data = df[(df.glass == 'вина_по_бокалам_150_мл')]

# %%
data = data[data.open_time.notna()]

# %%
data.groupby('only_glass_cat')['glass_price'].agg('sum')
# Out:
# Series([], Name: glass_price, dtype: float64)

# %%
data.groupby('only_glass_cat')['final_sum'].agg('sum')
# Out:
# Series([], Name: final_sum, dtype: float64)

# %%
data = add_time_columns(data)

# %%
data
# Out:
# Empty DataFrame
# Columns: [open_time, article_name, price, quantity, final_sum, article_category, only_glass_cat, article_price, article_profit, glass, glass_price, glass_profit, month, day, hour, month_year]
# Index: []

# %%
data.groupby(['only_glass_cat', 'month'], as_index=False)['final_sum'].agg('sum')
# Out:
# Empty DataFrame
# Columns: [only_glass_cat, month, final_sum]
# Index: []

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from calendar import month_name

# 1) Готовим данные: сумма по категориям × месяцам
# Если у тебя уже есть такой groupby — можно начать с него.
grp = (
    data.groupby(['only_glass_cat', 'month'], as_index=False)['final_sum']
        .sum()
)

# 2) Делаем порядок месяцев календарным
# (если 'month' у тебя уже datetime/Period — замени на .dt.month_name())
all_months = [m for m in month_name if m]  # ['January', 'February', ... 'December']
cat_type = pd.api.types.CategoricalDtype(categories=all_months, ordered=True)
grp['month'] = grp['month'].astype(cat_type)

# 3) Список нужных категорий (4 штуки)
cats = ['белые_вина', 'дижестивы_оранжи', 'игристые', 'красные_вина']

# 4) Рисуем 2×2 субплота
fig, axes = plt.subplots(2, 2, figsize=(12, 8), sharey=True)
axes = axes.ravel()

for i, cat in enumerate(cats):
    ax = axes[i]
    # данные по категории; реиндекс по всем месяцам, чтобы отсутствующие были 0
    dfc = (
        grp.loc[grp['only_glass_cat'] == cat, ['month', 'final_sum']]
           .set_index('month')
           .reindex(all_months)              # календарный порядок
           .fillna(0.0)
           .reset_index()
           .rename(columns={'index': 'month'})
    )

    # Линейный график (можно заменить на bar — закомментированный код ниже)
    ax.plot(dfc['month'].astype(str), dfc['final_sum'], marker='o')
    # ax.bar(dfc['month'].astype(str), dfc['final_sum'])  # <- если хочешь столбики

    ax.set_title(cat)
    ax.set_xlabel('Месяц')
    ax.set_ylabel('Сумма продаж')
    ax.grid(True, linestyle='--', alpha=0.4)
    ax.tick_params(axis='x', rotation=45)

# Если категорий меньше 4 — уберём лишние оси
for j in range(len(cats), 4):
    fig.delaxes(axes[j])

fig.suptitle('Продажи по категориям бокалов (по месяцам)', fontsize=14, y=0.98)
fig.tight_layout()
plt.show()

# %%
df.head()
# Out:
#             open_time                  article_name   price  quantity  \
# 0 2024-10-04 22:22:00  альхайт вайнери хирафте хиа   6100.0       2.0
# 1 2025-08-23 18:53:00  альхайт вайнери хирафте хиа   7900.0       2.0
# 2 2025-07-08 20:07:00  альхайт вайнери хирафте хиа   7900.0       1.0
# 3 2024-11-16 18:51:00  альхайт вайнери хирафте хиа   6100.0       1.0
# 4 2025-05-10 18:04:00  альхайт вайнери хирафте хиа   7100.0       1.0
#
#    final_sum article_category only_glass_cat  article_price  article_profit  \
# 0     2440.0       белые_вина     белые_вина         7900.0          3040.6
# 1     3160.0       белые_вина     белые_вина         7900.0          3040.6
# 2     1580.0       белые_вина     белые_вина         7900.0          3040.6
# 3     1220.0       белые_вина     белые_вина         7900.0          3040.6
# 4     1420.0       белые_вина     белые_вина         7900.0          3040.6
#
#    glass  glass_price  glass_profit
# 0  бокал       1580.0        608.12
# 1  бокал       1580.0        608.12
# 2  бокал       1580.0        608.12
# 3  бокал       1580.0        608.12
# 4  бокал       1580.0        608.12

# %%
df.article_category.unique()
# Out:
# array(['белые_вина', 'вина_вне_карты', 'вина_по_бокалам_150_мл',
#        'дижестивы_оранжи', 'игристые', 'красные_вина'], dtype=object)

# %%
df.only_glass_cat.unique()
# Out:
# array(['белые_вина', 'вина_вне_карты', 'дижестивы_оранжи', 'игристые',
#        'красные_вина'], dtype=object)

# %%
df[(df.only_glass_cat == 'белые_вина') & (df.article_category == 'вина_по_бокалам_150_мл')].groupby('article_name').agg(
    amount=('final_sum', 'sum'),
    quantity=('quantity', 'sum')
).sort_values(by='amount')
# Out:
#                                                       amount  quantity
# article_name
# де бортоли вайнз фэмили селекшн нюэ австралия 1...    5911.0     15.00
# бодега аттис лиас финас альбариньо риас байшас ...   11800.0     10.00
# жан-морис раффо ле баффэ шинон долина луары фра...   13920.0     12.00
# трескаре алиготе резерв кубань россия 150 мл         19256.0     37.50
# букенхоутсклуф семильон франшхук юар 150 мл          36260.0     21.00
# домен вахау рислинг федершпиль рид лойбенберг в...   38415.0     50.00
# домен вахау грюнер вельтлинер федершпиль террас...   77130.0    125.00
# балаша фурминт токай венгрия 150 мл                 101824.0    165.00
# кальтерн кальдаро кей уайт трентино-альто адидж...  205792.9    376.65

# %%
df.head()
# Out:
#             open_time                  article_name   price  quantity  \
# 0 2024-10-04 22:22:00  альхайт вайнери хирафте хиа   6100.0       2.0
# 1 2025-08-23 18:53:00  альхайт вайнери хирафте хиа   7900.0       2.0
# 2 2025-07-08 20:07:00  альхайт вайнери хирафте хиа   7900.0       1.0
# 3 2024-11-16 18:51:00  альхайт вайнери хирафте хиа   6100.0       1.0
# 4 2025-05-10 18:04:00  альхайт вайнери хирафте хиа   7100.0       1.0
#
#    final_sum article_category only_glass_cat  article_price  article_profit  \
# 0     2440.0       белые_вина     белые_вина         7900.0          3040.6
# 1     3160.0       белые_вина     белые_вина         7900.0          3040.6
# 2     1580.0       белые_вина     белые_вина         7900.0          3040.6
# 3     1220.0       белые_вина     белые_вина         7900.0          3040.6
# 4     1420.0       белые_вина     белые_вина         7900.0          3040.6
#
#    glass  glass_price  glass_profit
# 0  бокал       1580.0        608.12
# 1  бокал       1580.0        608.12
# 2  бокал       1580.0        608.12
# 3  бокал       1580.0        608.12
# 4  бокал       1580.0        608.12

# %%
df = add_time_columns(df)

# %%
df.head()
# Out:
#             open_time                  article_name   price  quantity  \
# 0 2024-10-04 22:22:00  альхайт вайнери хирафте хиа   6100.0       2.0
# 1 2025-08-23 18:53:00  альхайт вайнери хирафте хиа   7900.0       2.0
# 2 2025-07-08 20:07:00  альхайт вайнери хирафте хиа   7900.0       1.0
# 3 2024-11-16 18:51:00  альхайт вайнери хирафте хиа   6100.0       1.0
# 4 2025-05-10 18:04:00  альхайт вайнери хирафте хиа   7100.0       1.0
#
#    final_sum article_category only_glass_cat  article_price  article_profit  \
# 0     2440.0       белые_вина     белые_вина         7900.0          3040.6
# 1     3160.0       белые_вина     белые_вина         7900.0          3040.6
# 2     1580.0       белые_вина     белые_вина         7900.0          3040.6
# 3     1220.0       белые_вина     белые_вина         7900.0          3040.6
# 4     1420.0       белые_вина     белые_вина         7900.0          3040.6
#
#    glass  glass_price  glass_profit     month       day  hour month_year
# 0  бокал       1580.0        608.12   October    Friday  22.0    2024-10
# 1  бокал       1580.0        608.12    August  Saturday  18.0    2025-08
# 2  бокал       1580.0        608.12      July   Tuesday  20.0    2025-07
# 3  бокал       1580.0        608.12  November  Saturday  18.0    2024-11
# 4  бокал       1580.0        608.12       May  Saturday  18.0    2025-05

# %%
cutoff = pd.to_datetime("2025-06-23")

df = df[df.open_time > cutoff]

# %%
df.head()
# Out:
#              open_time                  article_name   price  quantity  \
# 1  2025-08-23 18:53:00  альхайт вайнери хирафте хиа   7900.0       2.0
# 2  2025-07-08 20:07:00  альхайт вайнери хирафте хиа   7900.0       1.0
# 7  2025-07-11 20:00:00  альхайт вайнери хирафте хиа   7900.0       1.0
# 8  2025-08-23 18:53:00  альхайт вайнери хирафте хиа   7900.0       3.0
# 10 2025-07-15 15:28:00  альхайт вайнери хирафте хиа   7900.0       2.0
#
#     final_sum article_category only_glass_cat  article_price  article_profit  \
# 1      3160.0       белые_вина     белые_вина         7900.0          3040.6
# 2      1580.0       белые_вина     белые_вина         7900.0          3040.6
# 7      1580.0       белые_вина     белые_вина         7900.0          3040.6
# 8      4740.0       белые_вина     белые_вина         7900.0          3040.6
# 10     3160.0       белые_вина     белые_вина         7900.0          3040.6
#
#     glass  glass_price  glass_profit   month       day  hour month_year
# 1   бокал       1580.0        608.12  August  Saturday  18.0    2025-08
# 2   бокал       1580.0        608.12    July   Tuesday  20.0    2025-07
# 7   бокал       1580.0        608.12    July    Friday  20.0    2025-07
# 8   бокал       1580.0        608.12  August  Saturday  18.0    2025-08
# 10  бокал       1580.0        608.12    July   Tuesday  15.0    2025-07

# %%
df[df.article_name == 'джулиана вичини розато коллине пескарези абруццо италия 150 мл']
# Out:
#                open_time                                       article_name  \
# 1653 2025-07-28 16:15:00  джулиана вичини розато коллине пескарези абруц...
# 1654 2025-08-05 14:41:00  джулиана вичини розато коллине пескарези абруц...
# 1655 2025-08-16 18:36:00  джулиана вичини розато коллине пескарези абруц...
# 1656 2025-07-28 16:15:00  джулиана вичини розато коллине пескарези абруц...
# 1658 2025-08-21 13:15:00  джулиана вичини розато коллине пескарези абруц...
# 1659 2025-07-15 20:28:00  джулиана вичини розато коллине пескарези абруц...
# 1660 2025-08-08 21:39:00  джулиана вичини розато коллине пескарези абруц...
# 1661 2025-08-01 19:47:00  джулиана вичини розато коллине пескарези абруц...
# 1662 2025-08-01 19:47:00  джулиана вичини розато коллине пескарези абруц...
# 1663 2025-08-01 19:47:00  джулиана вичини розато коллине пескарези абруц...
# 1664 2025-07-08 20:35:00  джулиана вичини розато коллине пескарези абруц...
# 1665 2025-07-08 20:35:00  джулиана вичини розато коллине пескарези абруц...
# 1666 2025-07-08 20:35:00  джулиана вичини розато коллине пескарези абруц...
# 1667 2025-07-14 21:53:00  джулиана вичини розато коллине пескарези абруц...
# 1668 2025-07-14 21:53:00  джулиана вичини розато коллине пескарези абруц...
# 1674 2025-07-24 21:30:00  джулиана вичини розато коллине пескарези абруц...
# 1675 2025-07-17 21:41:00  джулиана вичини розато коллине пескарези абруц...
# 1676 2025-08-11 21:49:00  джулиана вичини розато коллине пескарези абруц...
# 1677 2025-08-09 21:11:00  джулиана вичини розато коллине пескарези абруц...
# 1678 2025-07-23 22:30:00  джулиана вичини розато коллине пескарези абруц...
# 1679 2025-07-02 20:59:00  джулиана вичини розато коллине пескарези абруц...
# 1680 2025-08-26 21:34:00  джулиана вичини розато коллине пескарези абруц...
# 1681 2025-07-02 20:59:00  джулиана вичини розато коллине пескарези абруц...
# 1682 2025-08-26 21:34:00  джулиана вичини розато коллине пескарези абруц...
# 1683 2025-07-02 20:59:00  джулиана вичини розато коллине пескарези абруц...
#
#       price  quantity  final_sum        article_category    only_glass_cat  \
# 1653  580.0       1.0      580.0  вина_по_бокалам_150_мл  дижестивы_оранжи
# 1654  580.0       1.0      580.0  вина_по_бокалам_150_мл  дижестивы_оранжи
# 1655  580.0       1.0      493.0  вина_по_бокалам_150_мл  дижестивы_оранжи
# 1656  580.0       1.0      580.0  вина_по_бокалам_150_мл  дижестивы_оранжи
# 1658  580.0       1.0      580.0  вина_по_бокалам_150_мл  дижестивы_оранжи
# 1659  580.0       1.0      580.0  вина_по_бокалам_150_мл  дижестивы_оранжи
# 1660  580.0       1.0      580.0  вина_по_бокалам_150_мл  дижестивы_оранжи
# 1661  580.0       3.0     1740.0  вина_по_бокалам_150_мл  дижестивы_оранжи
# 1662  580.0       2.0     1160.0  вина_по_бокалам_150_мл  дижестивы_оранжи
# 1663  580.0       2.0     1160.0  вина_по_бокалам_150_мл  дижестивы_оранжи
# 1664  580.0       1.0      580.0  вина_по_бокалам_150_мл  дижестивы_оранжи
# 1665  580.0       1.0      580.0  вина_по_бокалам_150_мл  дижестивы_оранжи
# 1666  580.0       1.0      580.0  вина_по_бокалам_150_мл  дижестивы_оранжи
# 1667  580.0       2.0     1160.0  вина_по_бокалам_150_мл  дижестивы_оранжи
# 1668  580.0       2.0     1160.0  вина_по_бокалам_150_мл  дижестивы_оранжи
# 1674  580.0       2.0     1160.0  вина_по_бокалам_150_мл  дижестивы_оранжи
# 1675  580.0       2.0     1160.0  вина_по_бокалам_150_мл  дижестивы_оранжи
# 1676  580.0       2.0     1160.0  вина_по_бокалам_150_мл  дижестивы_оранжи
# 1677  580.0       1.0      580.0  вина_по_бокалам_150_мл  дижестивы_оранжи
# 1678  580.0       1.0      580.0  вина_по_бокалам_150_мл  дижестивы_оранжи
# 1679  580.0       1.0      493.0  вина_по_бокалам_150_мл  дижестивы_оранжи
# 1680  580.0       1.0      580.0  вина_по_бокалам_150_мл  дижестивы_оранжи
# 1681  580.0       2.0      986.0  вина_по_бокалам_150_мл  дижестивы_оранжи
# 1682  580.0       2.0     1160.0  вина_по_бокалам_150_мл  дижестивы_оранжи
# 1683  580.0       2.0      986.0  вина_по_бокалам_150_мл  дижестивы_оранжи
#
#       article_price  article_profit  glass  glass_price  glass_profit   month  \
# 1653          580.0          118.92  бокал        580.0        118.92    July
# 1654          580.0          118.92  бокал        580.0        118.92  August
# 1655          580.0          118.92  бокал        580.0        118.92  August
# 1656          580.0          118.92  бокал        580.0        118.92    July
# 1658          580.0          118.92  бокал        580.0        118.92  August
# 1659          580.0          118.92  бокал        580.0        118.92    July
# 1660          580.0          118.92  бокал        580.0        118.92  August
# 1661          580.0          118.92  бокал        580.0        118.92  August
# 1662          580.0          118.92  бокал        580.0        118.92  August
# 1663          580.0          118.92  бокал        580.0        118.92  August
# 1664          580.0          118.92  бокал        580.0        118.92    July
# 1665          580.0          118.92  бокал        580.0        118.92    July
# 1666          580.0          118.92  бокал        580.0        118.92    July
# 1667          580.0          118.92  бокал        580.0        118.92    July
# 1668          580.0          118.92  бокал        580.0        118.92    July
# 1674          580.0          118.92  бокал        580.0        118.92    July
# 1675          580.0          118.92  бокал        580.0        118.92    July
# 1676          580.0          118.92  бокал        580.0        118.92  August
# 1677          580.0          118.92  бокал        580.0        118.92  August
# 1678          580.0          118.92  бокал        580.0        118.92    July
# 1679          580.0          118.92  бокал        580.0        118.92    July
# 1680          580.0          118.92  бокал        580.0        118.92  August
# 1681          580.0          118.92  бокал        580.0        118.92    July
# 1682          580.0          118.92  бокал        580.0        118.92  August
# 1683          580.0          118.92  бокал        580.0        118.92    July
#
#             day  hour month_year
# 1653     Monday  16.0    2025-07
# 1654    Tuesday  14.0    2025-08
# 1655   Saturday  18.0    2025-08
# 1656     Monday  16.0    2025-07
# 1658   Thursday  13.0    2025-08
# 1659    Tuesday  20.0    2025-07
# 1660     Friday  21.0    2025-08
# 1661     Friday  19.0    2025-08
# 1662     Friday  19.0    2025-08
# 1663     Friday  19.0    2025-08
# 1664    Tuesday  20.0    2025-07
# 1665    Tuesday  20.0    2025-07
# 1666    Tuesday  20.0    2025-07
# 1667     Monday  21.0    2025-07
# 1668     Monday  21.0    2025-07
# 1674   Thursday  21.0    2025-07
# 1675   Thursday  21.0    2025-07
# 1676     Monday  21.0    2025-08
# 1677   Saturday  21.0    2025-08
# 1678  Wednesday  22.0    2025-07
# 1679  Wednesday  20.0    2025-07
# 1680    Tuesday  21.0    2025-08
# 1681  Wednesday  20.0    2025-07
# 1682    Tuesday  21.0    2025-08
# 1683  Wednesday  20.0    2025-07

# %%
df[df.article_name == 'джулиана вичини розато коллине пескарези абруццо италия 150 мл']['quantity'].sum()
# Out:
# np.float64(37.0)

# %%
df.to_excel('report_dish_new_menu.xlsx')
